# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, Normalizer, StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %%
import mysql.connector

# %%
db_config = {
    'host': 'localhost',
    'user': 'root',
    'password': 'Caracolillo666',
    'database': 'sakila',
}

# Establecer la conexión y el cursor
connection = mysql.connector.connect(**db_config)
cursor = connection.cursor()

# Consulta y creación de la tabla para mayo
create_table_may_query = """
CREATE TABLE IF NOT EXISTS rentals_may AS
SELECT *
FROM rental
WHERE MONTH(rental_date) = 5;
"""
cursor.execute(create_table_may_query)
connection.commit()

select_may_query = """
SELECT customer_id, COUNT(*) AS rental_count
FROM rentals_may
GROUP BY customer_id;
"""
cursor.execute(select_may_query)
results_may = cursor.fetchall()

print("Results of the first query (May):")
for row in results_may:
    print(f"Customer ID: {row[0]}, Rental Count: {row[1]}")

create_table_june_query = """
CREATE TABLE IF NOT EXISTS rentals_june AS
SELECT *
FROM rental
WHERE MONTH(rental_date) = 6;
"""
cursor.execute(create_table_june_query)
connection.commit()

select_june_query = """
SELECT customer_id, COUNT(*) AS rental_count
FROM rentals_june
GROUP BY customer_id;
"""
cursor.execute(select_june_query)
results_june = cursor.fetchall()

print("\nResults of the second query (June):")
for row in results_june:
    print(f"Customer ID: {row[0]}, Rental Count: {row[1]}")

cursor.close()
connection.close()
# Out:
# Results of the first query (May):
# Customer ID: 130, Rental Count: 4
# Customer ID: 459, Rental Count: 2
# Customer ID: 408, Rental Count: 6
# Customer ID: 333, Rental Count: 2
# Customer ID: 222, Rental Count: 10
# Customer ID: 549, Rental Count: 8
# Customer ID: 269, Rental Count: 12
# Customer ID: 239, Rental Count: 12
# Customer ID: 126, Rental Count: 6
# Customer ID: 399, Rental Count: 6
# Customer ID: 142, Rental Count: 6
# Customer ID: 261, Rental Count: 8
# Customer ID: 334, Rental Count: 4
# Customer ID: 446, Rental Count: 6
# Customer ID: 319, Rental Count: 6
# Customer ID: 316, Rental Count: 6
# Customer ID: 575, Rental Count: 10
# Customer ID: 19, Rental Count: 12
# Customer ID: 456, Rental Count: 2
# Customer ID: 185, Rental Count: 6
# Customer ID: 388, Rental Count: 4
# Customer ID: 509, Rental Count: 4
# Customer ID: 438, Rental Count: 6
# Customer ID: 350, Rental Count: 4
# Customer ID: 37, Rental Count: 4
# Customer ID: 371, Rental Count: 12
# ...
